# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plot
import rigol_plot as rigol

usb = rigol.list_device()
if len(usb)<1:
    adr = u'TCPIP::10.5.78.184::INSTR'
else:
    adr = usb[0]
print(adr)

time, data = rigol.read(adr)

# See if we should use a different time axis
if (time[-1] < 1e-3):
    time = time * 1e6
    tUnit = "uS"
elif (time[-1] < 1):
    time = time * 1e3
    tUnit = "mS"
else:
    tUnit = "S"

# Plot the data
plot.plot(time, data)
plot.title("Oscilloscope Channel 1")
plot.ylabel("Voltage (V)")
plot.xlabel("Time (" + tUnit + ")")
plot.xlim(time[0], time[-1])
plot.show()

# %%
import numpy
import matplotlib.pyplot as plot
import sys
import visa

class ResourceManager(object):
    def __init__(self, **kwargs):
        #self.rm = visa.ResourceManager(**kwargs)
        self.rm = visa.ResourceManager('@py',**kwargs)

    def __enter__(self):
        return(self.rm)

    def __exit__(self, exc_type, exc, exc_tb):
        del(self.rm)


class Instrument(object):    
    def __init__(self, rm, resource_name, **kwargs):
        self.inst = rm.open_resource(resource_name, **kwargs)
    def __enter__(self):
        return(self.inst)

    def __exit__(self, exc_type, exc, exc_tb):
        self.inst.close()

#usb = list(filter(lambda x: 'USB' in x, instruments))
#adr = usb[0]

adr = "TCPIP::10.5.78.184::INSTR"

#scope = rm.open_resource(usb[0], 
#                         timeout=20, 
#                         chunk_size=1024000, 
#                         write_termination=u'\r', #u'\n\x00'
#                         read_termination=u'\r',  #u'\n\x00'
#                         encoding = 'utf8' 
#                         )
#scope.data_bits=5
#scope.StopBits=1
#scope.SerialTermination.last_bit = scope.SerialTermination.last_bit

with ResourceManager() as rm:
    instruments = rm.list_resources()

    #with Instrument(rm, adr, encoding = 'utf8') as scope:
    with Instrument(rm, adr) as scope:
        print(scope.query(u'*IDN?\n'))
        scope.write(":STOP")

        timescale = float(scope.query(u':TIM:SCAL?\n'))
        timeoffset = float(scope.query(u':TIM:OFFS?\n'))
        voltscale = float(scope.query(u':CHAN1:SCAL?\n'))
        voltoffset = float(scope.query(u':CHAN1:OFFS?\n'))
        sample_rate = scope.query(u':ACQuire:SRATe?\n')

        scope.write(u':WAVeform:MODE RAW\n')
        scope.write(u':WAVeform:FORMat BYTE\n')
        #rawdata = scope.query(":WAV:DATA? CHAN1").encode('ascii')[10:]
        rawdata = scope.query_binary_values(u':WAV:DATA? CHAN1\n',
                                            datatype='B',
                                            container = numpy.array,
                                            is_big_endian  =False)
        #print([chr(x) for x in rawdata[0:10]])
        #print([255-x for x in rawdata[0:10]])
        #rawdata = scope.query_binary_values(":WAV:DATA? CHAN1")
        #print([hex(x) for x in rawdata])
        #print(bin(rawdata))
        #rawdata = scope.read_raw()
        #print(rawdata)
        rawdata = rawdata[10:-1]
            
        scope.write(u':RUN\n')
        #scope.close()

data = numpy.frombuffer(rawdata[:-1], 'B')
#print(data)
data =  255 - data
#print(data)
data = (data - 130.0 - voltoffset/voltscale*25) / 25 * voltscale
#print(data)

time = numpy.linspace(timeoffset - 6 * timescale, timeoffset + 6 * timescale, num=len(data))
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# <ipython-input-3-d26041cb09f1> in <module>()
#      45
#      46     #with Instrument(rm, adr, encoding = 'utf8') as scope:
# ---> 47     with Instrument(rm, adr) as scope:
#      48         print(scope.query(u'*IDN?\n'))
#      49         scope.write(":STOP")
#
# <ipython-input-3-d26041cb09f1> in __init__(self, rm, resource_name, **kwargs)
#      18 class Instrument(object):
#      19     def __init__(self, rm, resource_name, **kwargs):
# ---> 20         self.inst = rm.open_resource(resource_name, **kwargs)
#      21     def __enter__(self):
#      22         return(self.inst)
#
# ~/anaconda3/lib/python3.6/site-packages/pyvisa/highlevel.py in open_resource(self, resource_name, access_mode, open_timeout, resource_pyclass, **kwargs)
#    1642                 raise ValueError('%r is not a valid attribute for type %s' % (key, res.__class__.__name__))
#    1643
# -> 1644         res.open(access_mode, open_timeout)
#    1645
#    1646         for key, value in kwargs.items():
#
# ~/anaconda3/lib/python3.6/site-packages/pyvisa/resources/resource.py in open(self, access_mode, open_timeout)
#     201         logger.debug('%s - opening ...', self._resource_name, extra=self._logging_extra)
#     202         with self._resource_manager.ignore_warning(constants.VI_SUCCESS_DEV_NPRESENT):
# --> 203             self.session, status = self._resource_manager.open_bare_resource(self._resource_name, access_mode, open_timeout)
#     204
#     205             if status == constants.VI_SUCCESS_DEV_NPRESENT:
#
# ~/anaconda3/lib/python3.6/site-packages/pyvisa/highlevel.py in open_bare_resource(self, resource_name, access_mode, open_timeout)
#    1599         :return: Unique logical identifier reference to a session.
#    1600         """
# -> 1601         return self.visalib.open(self.session, resource_name, access_mode, open_timeout)
#    1602
#    1603     def open_resource(self, resource_name,
#
# ~/anaconda3/lib/python3.6/site-packages/pyvisa-py/highlevel.py in open(self, session, resource_name, access_mode, open_timeout)
#     189         cls = sessions.Session.get_session_class(parsed.interface_type_const, parsed.resource_class)
#     190
# --> 191         sess = cls(session, resource_name, parsed)
#     192
#     193         return self._register(sess), constants.StatusCode.success
#
# ~/anaconda3/lib/python3.6/site-packages/pyvisa-py/sessions.py in __init__(self, resource_manager_session, resource_name, parsed)
#     182                       constants.VI_ATTR_RSRC_CLASS: parsed.resource_class,
#     183                       constants.VI_ATTR_INTF_TYPE: parsed.interface_type}
# --> 184         self.after_parsing()
#     185
#     186     def after_parsing(self):
#
# ~/anaconda3/lib/python3.6/site-packages/pyvisa-py/tcpip.py in after_parsing(self)
#      48         # TODO: board_number not handled
#      49         # TODO: lan_device_name not handled
# ---> 50         self.interface = vxi11.CoreClient(self.parsed.host_address)
#      51
#      52         self.lock_timeout = 10000
#
# ~/anaconda3/lib/python3.6/site-packages/pyvisa-py/protocols/vxi11.py in __init__(self, host)
#     195         self.packer = Vxi11Packer()
#     196         self.unpacker = Vxi11Unpacker('')
# --> 197         super(CoreClient, self).__init__(host, DEVICE_CORE_PROG, DEVICE_CORE_VERS)
#     198
#     199     def create_link(self, id, lock_device, lock_timeout, name):
#
# ~/anaconda3/lib/python3.6/site-packages/pyvisa-py/protocols/rpc.py in __init__(self, host, prog, vers)
#     593     """
#     594     def __init__(self, host, prog, vers):
# --> 595         pmap = TCPPortMapperClient(host)
#     596         port = pmap.get_port((prog, vers, IPPROTO_TCP, 0))
#     597         pmap.close()
#
# ~/anaconda3/lib/python3.6/site-packages/pyvisa-py/protocols/rpc.py in __init__(self, host)
#     571
#     572     def __init__(self, host):
# --> 573         RawTCPClient.__init__(self, host, PMAP_PROG, PMAP_VERS, PMAP_PORT)
#     574         PartialPortMapperClient.__init__(self)
#     575
#
# ~/anaconda3/lib/python3.6/site-packages/pyvisa-py/protocols/rpc.py in __init__(self, host, prog, vers, port)
#     332     def __init__(self, host, prog, vers, port):
#     333         Client.__init__(self, host, prog, vers, port)
# --> 334         self.connect()
#     335
#     336     def connect(self):
#
# ~/anaconda3/lib/python3.6/site-packages/pyvisa-py/protocols/rpc.py in connect(self)
#     337         logger.debug('RawTCPClient: connecting to socket at (%s, %s)', self.host, self.port)
#     338         self.sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
# --> 339         self.sock.connect((self.host, self.port))
#     340
#     341     def close(self):
#
# TimeoutError: [Errno 110] Connection timed out

# %%
import numpy
numpy.frombuffer?
